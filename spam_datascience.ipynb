# %%
import pandas as pd

# Specify the encoding explicitly
spam_train = pd.read_csv("spam.csv", encoding="latin-1")

print(spam_train)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
spam_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
spam_train.head(10)
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...        NaN
# 6   ham  Even my brother is not like to speak with me. ...        NaN
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...        NaN
# 8  spam  WINNER!! As a valued network customer you have...        NaN
# 9  spam  Had your mobile 11 months or more? U R entitle...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# 5        NaN        NaN
# ...

# %%
spam_train.tail(10)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 5562   ham  Ok lor... Sony ericsson salesman... I ask shuh...        NaN
# 5563   ham                                Ard 6 like dat lor.        NaN
# 5564   ham  Why don't you wait 'til at least wednesday to ...        NaN
# 5565   ham                                       Huh y lei...        NaN
# 5566  spam  REMINDER FROM O2: To get 2.50 pounds free call...        NaN
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5562        NaN        NaN
# 5563        NaN        NaN
# 5564        NaN        NaN
# 5565        NaN        NaN
# ...

# %%
spam_train.shape
# Out:
# (5572, 5)

# %% [markdown]
# 1. Data Cleaning

# %%
spam_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
spam_train.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
spam_train.sample(5)
# Out:
#        v1                                                 v2
# 5220  ham                I have to take exam with in march 3
# 4128  ham               Me i'm not workin. Once i get job...
# 2971  ham  Sary just need Tim in the bollox &it hurt him ...
# 1540  ham               K come to nordstrom when you're done
# 3110  ham               Short But Cute : \ Be a good person

# %%
spam_train.rename(columns={'v1':'target','v2':'text'},inplace=True)
spam_train.sample(5)
# Out:
#      target                                               text
# 646     ham  Do you mind if I ask what happened? You dont h...
# 2949    ham  Where are you ? You said you would be here whe...
# 3336    ham                 I AM AT THE GAS STATION. GO THERE.
# 4457    ham  Die... I accidentally deleted e msg i suppose ...
# 3866    ham         Alright we're hooked up, where you guys at

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# Instantiate the LabelEncoder
encoder = LabelEncoder()

# Fit and transform the target column
spam_train['target'] = encoder.fit_transform(spam_train['target'])

# %%
spam_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  5572 non-null   int32
#  1   text    5572 non-null   object
# dtypes: int32(1), object(1)
# memory usage: 65.4+ KB

# %%
spam_train.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
spam_train.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
spam_train.duplicated().sum()#check for duplicate values and the sum we got is 403
# Out:
# 403

# %%
spam_train=spam_train.drop_duplicates(keep='first') #remove duplicates

# %%
spam_train.duplicated().sum()
# Out:
# 0

# %%
spam_train.shape
# Out:
# (5169, 2)

# %% [markdown]
# Data Exploration

# %%
spam_train.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
spam_train['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(spam_train['target'].value_counts(),labels=['ham','spam'],autopct="%0.2f")
plt.show()

# %%
#Big chunk of ham and very less spam so our data is not balanced

# %%
import nltk#natural language toolkit(unsupervised wave )(studying the words which are in the different format and helps to read the data)

# %%
spam_train['num_characters']=spam_train['text'].apply(len)

# %%
spam_train.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
#number of words calculation.
import nltk
spam_train['num_words']=spam_train['text'].apply(lambda x: len(nltk.word_tokenize(x)))#words count

# %%
spam_train.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
spam_train['num_sentences']=spam_train['text'].apply(lambda x: len(nltk.word_tokenize(x))) #words sentences count

# %%
spam_train.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24             24
# 1          8              8
# 2         37             37
# 3         13             13
# 4         15             15

# %%
spam_train['num_characters']=spam_train['text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
spam_train.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...              24
# 1       0                      Ok lar... Joking wif u oni...               8
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              37
# 3       0  U dun say so early hor... U c already then say...              13
# 4       0  Nah I don't think he goes to usf, he lives aro...              15
#
#    num_words  num_sentences
# 0         24             24
# 1          8              8
# 2         37             37
# 3         13             13
# 4         15             15

# %%
spam_train[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        18.455794    18.455794      18.455794
# std         13.324758    13.324758      13.324758
# min          1.000000     1.000000       1.000000
# 25%          9.000000     9.000000       9.000000
# 50%         15.000000    15.000000      15.000000
# 75%         26.000000    26.000000      26.000000
# max        220.000000   220.000000     220.000000

# %%
#targeting ham
spam_train[spam_train['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        17.123782    17.123782      17.123782
# std         13.493970    13.493970      13.493970
# min          1.000000     1.000000       1.000000
# 25%          8.000000     8.000000       8.000000
# 50%         13.000000    13.000000      13.000000
# 75%         22.000000    22.000000      22.000000
# max        220.000000   220.000000     220.000000

# %%
import seaborn as sns

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.histplot(spam_train[spam_train['target'] == 0]['num_characters'])
sns.histplot(spam_train[spam_train['target'] == 1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.histplot(spam_train[spam_train['target'] == 0]['num_words'])
sns.histplot(spam_train[spam_train['target'] == 1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.histplot(spam_train[spam_train['target'] == 0]['num_sentences'])
sns.histplot(spam_train[spam_train['target'] == 1]['num_sentences'],color='red')
# Out:
# <Axes: xlabel='num_sentences', ylabel='Count'>

# %%
sns.pairplot(spam_train,hue='target')

# %%
import seaborn as sns
sns.heatmap(spam_train.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[153], line 2
#       1 import seaborn as sns
# ----> 2 sns.heatmap(spam_train.corr(),annot=True)
#
# File c:\Users\JAHNAVI K\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\JAHNAVI K\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %% [markdown]
# The above code gives the error message because it couldn't convert String to float in heatmap.So in order to do this we must convert Strings data to float .For that we use(numeric_spam_train = spam_train.select_dtypes(include=['number']))hence it is working.

# %%
# Assuming spam_train is your DataFrame with non-numeric columns
# Drop non-numeric columns or convert them to numeric if possible
# For example, if a column contains categorical data, you might convert it using pd.get_dummies()

# Drop non-numeric columns
numeric_spam_train = spam_train.select_dtypes(include=['number'])

# Or convert non-numeric columns to numeric if possible
# For example, if a column contains categorical data, you might convert it using pd.get_dummies()
# numeric_spam_train = pd.get_dummies(spam_train)

# Generate heatmap
import seaborn as sns
sns.heatmap(numeric_spam_train.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Data Processing
# -Lower case(converting the text to lower case)
# -Tokenization(Breaking the sentences into words)
# -Removing special characters()
# -Removing stop words and punctuation
# -Stemming(eg dancing will be converted to dance)

# %%
import re #regular expressions(regex)
from nltk.tokenize import word_tokenize #module used to break text into indidvidual words or tokens
from nltk.corpus import stopwords #this imports 'stopwords' corpus from 'nltk' (e.g.'the','and','is')
from nltk.stem import PorterStemmer#converting running,dancing to dance,run
text="Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat..."
text=text.lower()

#tokenization breaking the sentences into words
words=word_tokenize(text)

#Define regular expression pattern to remove special characters
pattern=r'[^a-zA-Z0-9]'

#remove special characters
words=[re.sub(pattern,'',word)for word in words]

#remove stop words and punctuation
stop_words = set(stopwords.words('english'))
words = [word for word in words if word not in stop_words and word.isalnum()]

# Stemming: Convert words to their root form
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in words]

# Print processed words
print("Processed words:", stemmed_words)
# Out:
# Processed words: ['go', 'jurong', 'point', 'crazi', 'avail', 'bugi', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine', 'got', 'amor', 'wat']

# %%
spam_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5169 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   target          5169 non-null   int32
#  1   text            5169 non-null   object
#  2   num_characters  5169 non-null   int64
#  3   num_words       5169 non-null   int64
#  4   num_sentences   5169 non-null   int64
# dtypes: int32(1), int64(3), object(1)
# memory usage: 222.1+ KB

# %%
spam_train['text'][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
ps.stem('walking')
# Out:
# 'walk'

# %%
spam_train.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...              24
# 1       0                      Ok lar... Joking wif u oni...               8
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              37
# 3       0  U dun say so early hor... U c already then say...              13
# 4       0  Nah I don't think he goes to usf, he lives aro...              15
#
#    num_words  num_sentences
# 0         24             24
# 1          8              8
# 2         37             37
# 3         13             13
# 4         15             15

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Join the processed words into a single string
processed_text = ' '.join(stemmed_words)#calling thw words from the above code

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(processed_text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

# Load your spam dataset
# Assuming you have a DataFrame named spam_train with a column 'text' containing the text data
# Example: spam_train = pd.read_csv('spam_dataset.csv')

# Perform text preprocessing
def preprocess_text(text):
    text = text.lower()
    words = word_tokenize(text)
    pattern = r'[^a-zA-Z0-9]'
    words = [re.sub(pattern, '', word) for word in words]
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words and word.isalnum()]
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in words]
    return ' '.join(stemmed_words)

# Apply preprocessing to the text column of the DataFrame
spam_train['processed_text'] = spam_train['text'].apply(preprocess_text)

# Join the processed words into a single string
processed_text = ' '.join(spam_train['processed_text'])

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(processed_text)

# Display the word cloud using matplotlib
plt.figure(figsize=(9, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
spam_corpus=[]
for msg in spam_train[spam_train['target'] == 1]['text'].tolist():
    for word in msg:
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 90043

# %%
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming spam_corpus is a list containing words from the spam corpus
# If spam_corpus is a string containing all spam messages concatenated, you need to tokenize it first
# For example:
# spam_corpus = word_tokenize(spam_corpus_string)

# Create a Counter object to count word frequencies
word_counter = Counter(spam_corpus) #helps to count hashable objects

# Get the 30 most common words and their frequencies
most_common_words = word_counter.most_common(30)

# Create a DataFrame from the most common words
df_most_common = pd.DataFrame(most_common_words, columns=['Word', 'Frequency'])

# Create a bar plot using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Word', y='Frequency', data=df_most_common)
plt.xticks(rotation=90)  # Rotate x-axis labels to vertical
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Top 30 Most Common Words in Spam Corpus')
plt.show()
